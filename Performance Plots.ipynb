# %%
# %load_ext rmagic
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
# %%R --width=900 --height=500
# require(ggplot2)
# df = read.csv('http://mdtraj-performance.appspot.com/dump')
# print(summary(df))
# p = ggplot(df, aes(x=Time)) + \
#   geom_point(aes(y=Duration, group=Test.ID, color=Test.ID))
# print(p)
# Out:
#                   Time                                      Git.Revision
#  2013-05-03 06:03:40:12   978d6219985e7df1e513d83d8763fa4e251c5d48:12
#  2013-05-03 06:04:02:12   f5eae949b328107483aa82daa8fafaa2eb1b67a5:12
#
#
#
#
#
#     Duration
#  Min.   :0.02523
#  1st Qu.:0.09560
#  Median :0.14035
#  Mean   :0.26138
#  3rd Qu.:0.38737
#  Max.   :0.76908
#
#                                                             Docstring
#  Test the read speed of the BINPOS code (10000 frames, 100 atoms): 2
#  Test the read speed of the DCD code (10000 frames, 100 atoms)   : 2
#  Test the read speed of the NetCDF code (10000 frames, 100 atoms): 2
#  Test the read speed of the TRR code (10000 frames, 100 atoms)   : 2
#  Test the read speed of the XTC code (10000 frames, 100 atoms)   : 2
#  Test the read speed of the hdf5 code (10000 frames, 100 atoms)  : 2
#  (Other)                                                         :12
#                                 Test.ID
# ...

# %%
# %%R --width=900 --height=500
# p =  ggplot(df) + \
#   geom_bar(aes(x=Test.ID, fill=Test.ID, y=Duration), stat="identity")
# print(p)
